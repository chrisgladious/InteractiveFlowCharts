# %%
import os
# os.chdir(r'C:\Users\secn17444\OneDrive - WSP O365\pyproj\flow_env\src')
import pandas as pd
import openpyxl

# Define the path to the CSV file
csv_file_path = r"C:\Users\secn17444\Downloads\SMHI\Dansjön (2335) vattenföring\smhi-opendata_2_2335_20250212_141900.csv"

# Read the CSV file into a DataFrame
df_axL = pd.read_csv(csv_file_path, sep=';', skiprows=6)
df_axL.set_index('Datum Tid (UTC)', inplace=True)
df_axR = pd.DataFrame()
# df_axR['Vattenföring kumsum [m3]'] = df_axL['Vattenföring (15 min)'].cumsum()
# Display the first few rows of the DataFrame
df_axL.head()

# Check if the DataFrame is not None and has the expected columns before dropping
if df_axL is not None and len(df_axL.columns) > 3:
    df_axL.drop(df_axL.columns[[1,2,3]], axis=1, inplace=True)

from InteractivePlotWindow import dprint
dprint(len(df_axL))
# Out:
# len(df_axL) = 1463227
# C:\temp\ipykernel_10944\1650583006.py:10: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_axL = pd.read_csv(csv_file_path, sep=';', skiprows=6)

# %%
# Drop rows after a certain row
# For example, to keep rows up to '1983-05-17 13:00:00' and drop the rest
# cutoff_index = '1983-06-17 13:00:00'
# df_axL = df_axL.loc[:cutoff_index]
chartStartRow = 1
chartStopRow = 10000
df_axL_slice = df_axL.iloc[chartStartRow:chartStopRow]

# df_axR.index = df_axL.index

# %%
# Import the necessary components from Örsled_PST.py
from InteractivePlotWindow import InteractivePlotWindow, dprint
# Example usage of PlotWindow
import pandas as pd
from PyQt6.QtWidgets import QApplication
import sys
# # Initialize the QApplication
app = QApplication(sys.argv)

# Create and show the PlotWindow
mainWin = InteractivePlotWindow(df_axL=df_axL_slice,
                                df_axL_Title='Flöde [m³/s]',
                                df_axR_Title='Cumulative [m³]', 
                                WindowTitle='Dansjön (2335) vattenföring')
mainWin.show()

# Start the event loop
sys.exit(app.exec())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# c:\Users\secn17444\OneDrive - WSP O365\pyproj\InteractiveFlowCharts\venv\Lib\site-packages\IPython\core\interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
